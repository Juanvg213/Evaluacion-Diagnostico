# %%
# Python program to read
# json file
 
import json
import pandas as pd
 


# Read JSON file containing tweets data and removce tweets not in English

raw_tweets = pd.read_json(r'data/data.json', lines=True)
print("Shape: ", raw_tweets.shape)
raw_tweets.head(5)
# Out:
# Shape:  (419507, 21)
#                                                  url  \
# 0  https://twitter.com/ShashiRajbhar6/status/1376...
# 1  https://twitter.com/kaursuk06272818/status/137...
# 2  https://twitter.com/kaursuk06272818/status/137...
# 3  https://twitter.com/SukhdevSingh_/status/13767...
# 4  https://twitter.com/Davidmu66668113/status/137...
#
#                        date  \
# 0 2021-03-30 03:33:46+00:00
# 1 2021-03-30 03:33:23+00:00
# 2 2021-03-30 03:31:00+00:00
# 3 2021-03-30 03:30:45+00:00
# 4 2021-03-30 03:30:30+00:00
#
#                                              content  \
# 0                       Support 👇\n\n#FarmersProtest
# 1  Supporting farmers means supporting our countr...
# 2  Support farmers if you are related to food #St...
# 3  #StopHateAgainstFarmers support #FarmersProtes...
# 4  You hate farmers I hate you, \nif you love the...
#
#                                      renderedContent                   id  \
# ...

# %%
def most_retweeted(raw_tweets):
    new_raw_tweets = raw_tweets.sort_values(by=['retweetCount'], ascending = False)
    df = new_raw_tweets.head(10)
    for row in df.iterrows():
        print(row)
# Out:
# (408128, url                https://twitter.com/rihanna/status/13566258896...
# date                                       2021-02-02 15:29:51+00:00
# content            why aren’t we talking about this?! #FarmersPro...
# renderedContent    why aren’t we talking about this?! #FarmersPro...
# id                                               1356625889602199552
# user               {'username': 'rihanna', 'displayname': 'Rihann...
# outlinks           [https://www.cnn.com/2021/02/01/asia/india-int...
# tcooutlinks                                [https://t.co/obmIlXhK9S]
# replyCount                                                    163065
# retweetCount                                                  315547
# likeCount                                                     944307
# quoteCount                                                     45832
# conversationId                                   1356625889602199552
# ...

# %%
def best_users(raw_tweets):
    df = raw_tweets.pivot_table(columns=['user'], aggfunc='size')
    print(df)
best
